# %% [markdown]
# ## Generate the mesh

# %%
from mesh import three_cubes

size = 0.03
filename = f"meshes/mesh_{size}.msh"

three_cubes(filename, size=size)
# Out:
# Info    : Meshing 1D...nts
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 20%] Meshing curve 4 (Line)
# Info    : [ 20%] Meshing curve 5 (Line)
# Info    : [ 20%] Meshing curve 6 (Line)
# Info    : [ 30%] Meshing curve 7 (Line)
# Info    : [ 30%] Meshing curve 8 (Line)
# Info    : [ 30%] Meshing curve 9 (Line)
# Info    : [ 40%] Meshing curve 10 (Line)
# Info    : [ 40%] Meshing curve 11 (Line)
# Info    : [ 40%] Meshing curve 12 (Line)
# Info    : [ 50%] Meshing curve 13 (Line)
# Info    : [ 50%] Meshing curve 14 (Line)
# Info    : [ 60%] Meshing curve 15 (Line)
# Info    : [ 60%] Meshing curve 16 (Line)
# Info    : [ 60%] Meshing curve 17 (Line)
# Info    : [ 70%] Meshing curve 18 (Line)
# Info    : [ 70%] Meshing curve 19 (Line)
# Info    : [ 70%] Meshing curve 20 (Line)
# Info    : [ 80%] Meshing curve 21 (Line)
# Info    : [ 80%] Meshing curve 22 (Line)
# Info    : [ 80%] Meshing curve 23 (Line)
# Info    : [ 90%] Meshing curve 24 (Line)
# Info    : [ 90%] Meshing curve 25 (Line)
# Info    : [ 90%] Meshing curve 26 (Line)
# Info    : [100%] Meshing curve 27 (Line)
# Info    : [100%] Meshing curve 28 (Line)
# Info    : Done meshing 1D (Wall 0.00133165s, CPU 0.001873s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 7 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 8 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 9 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 10 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 11 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 13 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 14 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 15 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 16 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.335958s, CPU 0.338195s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 3 volumes with 1 connected component
# Info    : Tetrahedrizing 21776 nodes...
# Info    : Done tetrahedrizing 21784 nodes (Wall 0.20385s, CPU 0.204526s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 1 Steiner point
# Info    : Done reconstructing mesh (Wall 0.526292s, CPU 0.51038s)
# Info    : Found volume 3
# Info    : Found volume 1
# Info    : Found volume 2
# Info    : It. 0 - 0 nodes created - worst tet radius 46.3229 (nodes removed 0 0)
# Info    : It. 500 - 494 nodes created - worst tet radius 4.40682 (nodes removed 0 6)
# Info    : It. 1000 - 994 nodes created - worst tet radius 3.74621 (nodes removed 0 6)
# Info    : It. 1500 - 1494 nodes created - worst tet radius 3.28349 (nodes removed 0 6)
# Info    : It. 2000 - 1994 nodes created - worst tet radius 2.99411 (nodes removed 0 6)
# Info    : It. 2500 - 2494 nodes created - worst tet radius 2.81444 (nodes removed 0 6)
# Info    : It. 3000 - 2994 nodes created - worst tet radius 2.67935 (nodes removed 0 6)
# Info    : It. 3500 - 3494 nodes created - worst tet radius 2.58885 (nodes removed 0 6)
# Info    : It. 4000 - 3994 nodes created - worst tet radius 2.48286 (nodes removed 0 6)
# Info    : It. 4500 - 4494 nodes created - worst tet radius 2.39484 (nodes removed 0 6)
# Info    : It. 5000 - 4994 nodes created - worst tet radius 2.30983 (nodes removed 0 6)
# Info    : It. 5500 - 5494 nodes created - worst tet radius 2.24496 (nodes removed 0 6)
# Info    :  - 1 Delaunay cavities modified for star shapeness
# Info    :  - 6 nodes could not be inserted
# Info    :  - 544654 tetrahedra created in 4.21145 sec. (129326 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 7.49579s, CPU 7.31935s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 1) with worst = 0.00343559 / average = 0.784304:
# Info    : 0.00 < quality < 0.10 :       398 elements
# Info    : 0.10 < quality < 0.20 :      1152 elements
# Info    : 0.20 < quality < 0.30 :      1980 elements
# Info    : 0.30 < quality < 0.40 :      3090 elements
# Info    : 0.40 < quality < 0.50 :      4934 elements
# Info    : 0.50 < quality < 0.60 :      7897 elements
# Info    : 0.60 < quality < 0.70 :     16947 elements
# Info    : 0.70 < quality < 0.80 :     39690 elements
# Info    : 0.80 < quality < 0.90 :     69936 elements
# Info    : 0.90 < quality < 1.00 :     35894 elements
# Info    : 3494 edge swaps, 132 node relocations (volume = 1): worst = 0.155667 / average = 0.79661 (Wall 0.0836581s, CPU 0.078387s)
# Info    : 3513 edge swaps, 133 node relocations (volume = 1): worst = 0.288699 / average = 0.796671 (Wall 0.107113s, CPU 0.101976s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :      3061 elements
# Info    : 0.40 < quality < 0.50 :      4766 elements
# Info    : 0.50 < quality < 0.60 :      7533 elements
# Info    : 0.60 < quality < 0.70 :     16793 elements
# Info    : 0.70 < quality < 0.80 :     40397 elements
# Info    : 0.80 < quality < 0.90 :     70553 elements
# Info    : 0.90 < quality < 1.00 :     35652 elements
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 1) with worst = 0.00281885 / average = 0.784019:
# Info    : 0.00 < quality < 0.10 :       343 elements
# Info    : 0.10 < quality < 0.20 :      1154 elements
# Info    : 0.20 < quality < 0.30 :      1983 elements
# Info    : 0.30 < quality < 0.40 :      3072 elements
# Info    : 0.40 < quality < 0.50 :      4785 elements
# Info    : 0.50 < quality < 0.60 :      8134 elements
# Info    : 0.60 < quality < 0.70 :     16892 elements
# Info    : 0.70 < quality < 0.80 :     40236 elements
# Info    : 0.80 < quality < 0.90 :     69137 elements
# Info    : 0.90 < quality < 1.00 :     35774 elements
# Info    : 3456 edge swaps, 91 node relocations (volume = 1): worst = 0.191467 / average = 0.796239 (Wall 0.0815345s, CPU 0.08198s)
# Info    : 3468 edge swaps, 91 node relocations (volume = 1): worst = 0.300007 / average = 0.796272 (Wall 0.100132s, CPU 0.100712s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :      3054 elements
# Info    : 0.40 < quality < 0.50 :      4580 elements
# Info    : 0.50 < quality < 0.60 :      7778 elements
# Info    : 0.60 < quality < 0.70 :     16704 elements
# Info    : 0.70 < quality < 0.80 :     40903 elements
# Info    : 0.80 < quality < 0.90 :     69783 elements
# Info    : 0.90 < quality < 1.00 :     35565 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 1) with worst = 0.00534691 / average = 0.785175:
# Info    : 0.00 < quality < 0.10 :       366 elements
# Info    : 0.10 < quality < 0.20 :      1020 elements
# Info    : 0.20 < quality < 0.30 :      1937 elements
# Info    : 0.30 < quality < 0.40 :      3025 elements
# Info    : 0.40 < quality < 0.50 :      4720 elements
# Info    : 0.50 < quality < 0.60 :      7925 elements
# Info    : 0.60 < quality < 0.70 :     16999 elements
# Info    : 0.70 < quality < 0.80 :     39849 elements
# Info    : 0.80 < quality < 0.90 :     69617 elements
# Info    : 0.90 < quality < 1.00 :     35757 elements
# Info    : 3298 edge swaps, 92 node relocations (volume = 1): worst = 0.192772 / average = 0.796668 (Wall 0.0716321s, CPU 0.071996s)
# Info    : 3310 edge swaps, 93 node relocations (volume = 1): worst = 0.219434 / average = 0.796706 (Wall 0.0879694s, CPU 0.088425s)
# Info    : 3311 edge swaps, 93 node relocations (volume = 1): worst = 0.22941 / average = 0.79671 (Wall 0.107744s, CPU 0.108347s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         6 elements
# Info    : 0.30 < quality < 0.40 :      2993 elements
# Info    : 0.40 < quality < 0.50 :      4554 elements
# Info    : 0.50 < quality < 0.60 :      7622 elements
# Info    : 0.60 < quality < 0.70 :     16936 elements
# Info    : 0.70 < quality < 0.80 :     40411 elements
# Info    : 0.80 < quality < 0.90 :     70223 elements
# Info    : 0.90 < quality < 1.00 :     35514 elements
# Info    : Done optimizing mesh (Wall 1.3069s, CPU 1.07429s)
# Info    : 95220 nodes 580177 elements
# Saving mesh to 'meshes/mesh_0.03.msh'...
# Info    : Writing '/home/remidm/festim-benchmark/case_1_simple/meshes/mesh_0.03.msh'...
# Mesh saved to 'meshes/mesh_0.03.msh'Info    : Done writing '/home/remidm/festim-benchmark/case_1_simple/meshes/mesh_0.03.msh'

# %%
from convert_mesh import convert_mesh

volume_file = f"meshes/mesh_{size}.xdmf"
facet_file = f"meshes/mesh_{size}_facet.xdmf"

print(filename, volume_file, facet_file)
nb_cells, nb_facets = convert_mesh(filename, volume_file, facet_file)
print(f"Mesh has {nb_cells} cells and {nb_facets} facets")
# Out:
# meshes/mesh_0.03.msh meshes/mesh_0.03.xdmf meshes/mesh_0.03_facet.xdmf
#
# Surface IDs:  [4 5 6 7]
# Volume IDs:  [1 2 3]
# Mesh has 535393 cells and 10960 facets

# %%
def run(volume_file: str, facet_file: str) -> float:
    from script_festim_2 import run_festim_2
    import time

    start = time.perf_counter()
    run_festim_2(volume_file, facet_file)
    end = time.perf_counter()

    elapsed_time = end - start


    return elapsed_time

# %%
import ipyparallel as ipp
import numpy as np

# check if we are in github actions
import os
if "CI" in os.environ:
    num_procs = [1, 2, 4]
else:
    num_procs = [1, 2, 4, 8, 16]

runtimes = np.zeros_like(num_procs, dtype=np.float64)

for i, num_proc in enumerate(num_procs):
    print(f"Running with {num_proc} processes")


    # start an ipyparallel cluster and connect to it
    cluster = ipp.Cluster(engines="mpi", n=num_proc)
    rc = cluster.start_and_connect_sync()

    # run the function run in parallel
    query = rc[:].apply_async(run, volume_file, facet_file)
    query.wait()

    # get the results for all processes
    elapsed_times = query.get()
    rc.cluster.stop_cluster_sync()
    cluster.stop_cluster()

    print(elapsed_times)
    rc.cluster.stop_cluster_sync()
    cluster.stop_cluster()

    runtime = np.max(elapsed_times)
    print(f"Elapsed times: {elapsed_times} seconds, max {runtime=:.2e}")

    runtimes[i] = runtime
# Out:
# Running with 1 processes
# Starting 1 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
# 100%|██████████| 1/1 [00:05<00:00,  5.75s/engine]
# [Engine Exception]:
# Traceback (most recent call last):
#
#   File "/home/remidm/miniconda3/envs/festim-benchmark-env/lib/python3.10/site-packages/ipyparallel/client/client.py", line 887, in _handle_stranded_msgs
#     raise error.EngineError(
#
# ipyparallel.error.EngineError: Engine 0 died while running task 'f545b833-6d670eb0338bd9443b280ceb_1543186_1'
# Output for ipengine-1730471996-y8w3-1730471997-1543186:
# --------------------------------------------------------------------------
# MPI_ABORT was invoked on rank 0 in communicator MPI COMM 5 DUP FROM 3
#   Proc: [[14420,1],0]
#   Errorcode: 6
#
# NOTE: invoking MPI_ABORT causes Open MPI to kill all MPI processes.
# You may or may not see output from other processes, depending on
# exactly when Open MPI kills them.
# --------------------------------------------------------------------------
# 1 more process has sent help message help-mpi-api.txt / mpi-abort
# 2024-11-01 10:39:58.128 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-11-01 10:39:58.128 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-11-01 10:39:58.319 [IPEngine] Registering with controller at tcp://127.0.0.1:54843
# 2024-11-01 10:39:58.321 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:57361', 'tcp://127.0.0.1:60649', 'tcp://127.0.0.1:39015']
# 2024-11-01 10:39:58.321 [IPEngine] Connecting shell to tcp://127.0.0.1:57361
# 2024-11-01 10:39:58.321 [IPEngine] Connecting shell to tcp://127.0.0.1:60649
# 2024-11-01 10:39:58.321 [IPEngine] Connecting shell to tcp://127.0.0.1:39015
# 2024-11-01 10:39:58.321 [IPEngine] Starting nanny
# 2024-11-01 10:39:58.510 [KernelNanny.0] Starting kernel nanny for engine 0, pid=1545539, nanny pid=1545543
# 2024-11-01 10:39:58.510 [KernelNanny.0] Nanny watching parent pid 1545539.
# 2024-11-01 10:39:58.574 [IPEngine] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-11-01 10:39:58.575 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-11-01 10:39:58.576 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-11-01 10:39:58.576 [IPEngine] Completed registration with id 0
# 2024-11-01 10:40:03.636 [IPEngine] Handling apply_request: f545b833-6d670eb0338bd9443b280ceb_1543186_1
# 2024-11-01 10:40:28.006 [KernelNanny.0] Pipe closed, parent 1545539 has status: zombie
# 2024-11-01 10:40:28.006 [KernelNanny.0] Notifying Hub that our parent has shut down
# 1 more process has sent help message help-mpi-api.txt / mpi-abort
#
# engine set stopped 1730471997: {'exit_code': 6, 'pid': 1545534, 'identifier': 'ipengine-1730471996-y8w3-1730471997-1543186'}

# %%
def run_change_of_var(volume_file: str, facet_file: str) -> float:
    from script_festim_2 import run_festim_2_change_of_var
    import time

    start = time.perf_counter()
    run_festim_2_change_of_var(volume_file, facet_file)
    end = time.perf_counter()

    elapsed_time = end - start


    return elapsed_time


import ipyparallel as ipp
import numpy as np

# check if we are in github actions
import os
if "CI" in os.environ:
    num_procs = [1, 2, 4]
else:
    num_procs = [1, 2, 4, 8, 16]

runtimes_change_of_var = np.zeros_like(num_procs, dtype=np.float64)

for i, num_proc in enumerate(num_procs):
    print(f"Running with {num_proc} processes")


    # start an ipyparallel cluster and connect to it
    cluster = ipp.Cluster(engines="mpi", n=num_proc)
    rc = cluster.start_and_connect_sync()

    # run the function run in parallel
    query = rc[:].apply_async(run_change_of_var, volume_file, facet_file)
    query.wait()

    # get the results for all processes
    elapsed_times = query.get()
    rc.cluster.stop_cluster_sync()
    cluster.stop_cluster()

    print(elapsed_times)
    rc.cluster.stop_cluster_sync()
    cluster.stop_cluster()

    runtime = np.max(elapsed_times)
    print(f"Elapsed times: {elapsed_times} seconds, max {runtime=:.2e}")

    runtimes_change_of_var[i] = runtime
# Out:
# Running with 1 processes
# Starting 1 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
# 100%|██████████| 1/1 [00:05<00:00,  5.52s/engine]
# Stopping controller
# Controller stopped: {'exit_code': 0, 'pid': 1447174, 'identifier': 'ipcontroller-1730405995-eoeq-1445715'}
# Stopping engine(s): 1730405996
# Output for ipengine-1730405995-eoeq-1730405996-1445715:
# 2024-10-31 16:19:56.279 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-10-31 16:19:56.279 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-10-31 16:19:56.405 [IPEngine] Registering with controller at tcp://127.0.0.1:54833
# 2024-10-31 16:19:56.407 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:57765', 'tcp://127.0.0.1:49857', 'tcp://127.0.0.1:38981']
# 2024-10-31 16:19:56.408 [IPEngine] Connecting shell to tcp://127.0.0.1:57765
# 2024-10-31 16:19:56.408 [IPEngine] Connecting shell to tcp://127.0.0.1:49857
# 2024-10-31 16:19:56.408 [IPEngine] Connecting shell to tcp://127.0.0.1:38981
# 2024-10-31 16:19:56.408 [IPEngine] Starting nanny
# 2024-10-31 16:19:56.603 [KernelNanny.0] Starting kernel nanny for engine 0, pid=1447207, nanny pid=1447214
# 2024-10-31 16:19:56.603 [KernelNanny.0] Nanny watching parent pid 1447207.
# 2024-10-31 16:19:56.635 [IPEngine] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:19:56.636 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:19:56.637 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:19:56.637 [IPEngine] Completed registration with id 0
# 2024-10-31 16:20:01.580 [IPEngine] Handling apply_request: 3462f73c-dd3ed9de74deed2c5415bcb3_1445715_1
#
# engine set stopped 1730405996: {'exit_code': 1, 'pid': 1447202, 'identifier': 'ipengine-1730405995-eoeq-1730405996-1445715'}
# [27.97554370999569]
# Elapsed times: [27.97554370999569] seconds, max runtime=2.80e+01
# Running with 2 processes
# /tmp/ipykernel_1445715/2137199539.py:42: RuntimeWarning: coroutine 'Cluster.stop_cluster' was never awaited
#   cluster.stop_cluster()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /tmp/ipykernel_1445715/2137199539.py:46: RuntimeWarning: coroutine 'Cluster.stop_cluster' was never awaited
#   cluster.stop_cluster()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Starting 2 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
# 100%|██████████| 2/2 [00:05<00:00,  2.76s/engine]
# Stopping controller
# Controller stopped: {'exit_code': 0, 'pid': 1447452, 'identifier': 'ipcontroller-1730406030-eog8-1445715'}
# Stopping engine(s): 1730406031
# Output for ipengine-1730406030-eog8-1730406031-1445715:
# 2024-10-31 16:20:31.552 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-10-31 16:20:31.552 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-10-31 16:20:31.556 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-10-31 16:20:31.556 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-10-31 16:20:31.606 [IPEngine.1] Registering with controller at tcp://127.0.0.1:43021
# 2024-10-31 16:20:31.606 [IPEngine.0] Registering with controller at tcp://127.0.0.1:43021
# 2024-10-31 16:20:31.607 [IPEngine.0] Requesting id: 0
# 2024-10-31 16:20:31.607 [IPEngine.1] Requesting id: 1
# 2024-10-31 16:20:31.608 [IPEngine.1] Shell_addrs: ['tcp://127.0.0.1:32815', 'tcp://127.0.0.1:52755', 'tcp://127.0.0.1:60795']
# 2024-10-31 16:20:31.609 [IPEngine.1] Connecting shell to tcp://127.0.0.1:32815
# 2024-10-31 16:20:31.609 [IPEngine.1] Connecting shell to tcp://127.0.0.1:52755
# 2024-10-31 16:20:31.609 [IPEngine.1] Connecting shell to tcp://127.0.0.1:60795
# 2024-10-31 16:20:31.609 [IPEngine.1] Starting nanny
# 2024-10-31 16:20:31.609 [IPEngine.0] Shell_addrs: ['tcp://127.0.0.1:32815', 'tcp://127.0.0.1:52755', 'tcp://127.0.0.1:58273']
# 2024-10-31 16:20:31.609 [IPEngine.0] Connecting shell to tcp://127.0.0.1:32815
# 2024-10-31 16:20:31.609 [IPEngine.0] Connecting shell to tcp://127.0.0.1:52755
# 2024-10-31 16:20:31.609 [IPEngine.0] Connecting shell to tcp://127.0.0.1:58273
# 2024-10-31 16:20:31.609 [IPEngine.0] Starting nanny
# 2024-10-31 16:20:31.842 [KernelNanny.1] Starting kernel nanny for engine 1, pid=1447486, nanny pid=1447499
# 2024-10-31 16:20:31.842 [KernelNanny.1] Nanny watching parent pid 1447486.
# 2024-10-31 16:20:31.850 [KernelNanny.0] Starting kernel nanny for engine 0, pid=1447485, nanny pid=1447500
# 2024-10-31 16:20:31.850 [KernelNanny.0] Nanny watching parent pid 1447485.
# 2024-10-31 16:20:31.880 [IPEngine.1] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:20:31.881 [IPEngine.1] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:20:31.883 [IPEngine.1] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:20:31.883 [IPEngine.1] Completed registration with id 1
# 2024-10-31 16:20:31.885 [IPEngine.0] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:20:31.887 [IPEngine.0] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:20:31.888 [IPEngine.0] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:20:31.888 [IPEngine.0] Completed registration with id 0
# 2024-10-31 16:20:36.833 [IPEngine.0] Handling apply_request: e1c5763d-5096194de16f644697ecfb07_1445715_1
# 2024-10-31 16:20:36.833 [IPEngine.1] Handling apply_request: e1c5763d-5096194de16f644697ecfb07_1445715_2
#
# engine set stopped 1730406031: {'exit_code': 1, 'pid': 1447480, 'identifier': 'ipengine-1730406030-eog8-1730406031-1445715'}
# [24.66698932100553, 24.66573788000096]
# Elapsed times: [24.66698932100553, 24.66573788000096] seconds, max runtime=2.47e+01
# Running with 4 processes
# /tmp/ipykernel_1445715/2137199539.py:42: RuntimeWarning: coroutine 'Cluster.stop_cluster' was never awaited
#   cluster.stop_cluster()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /tmp/ipykernel_1445715/2137199539.py:46: RuntimeWarning: coroutine 'Cluster.stop_cluster' was never awaited
#   cluster.stop_cluster()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Starting 4 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
# 100%|██████████| 4/4 [00:05<00:00,  1.38s/engine]
# Stopping controller
# Controller stopped: {'exit_code': 0, 'pid': 1447700, 'identifier': 'ipcontroller-1730406062-yqq5-1445715'}
# Stopping engine(s): 1730406063
# Output for ipengine-1730406062-yqq5-1730406063-1445715:
# 2024-10-31 16:21:03.485 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-10-31 16:21:03.485 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-10-31 16:21:03.485 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-10-31 16:21:03.485 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-10-31 16:21:03.486 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-10-31 16:21:03.486 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-10-31 16:21:03.486 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-10-31 16:21:03.486 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-10-31 16:21:03.558 [IPEngine.1] Registering with controller at tcp://127.0.0.1:38949
# 2024-10-31 16:21:03.558 [IPEngine.3] Registering with controller at tcp://127.0.0.1:38949
# 2024-10-31 16:21:03.558 [IPEngine.2] Registering with controller at tcp://127.0.0.1:38949
# 2024-10-31 16:21:03.558 [IPEngine.0] Registering with controller at tcp://127.0.0.1:38949
# 2024-10-31 16:21:03.558 [IPEngine.1] Requesting id: 1
# 2024-10-31 16:21:03.558 [IPEngine.3] Requesting id: 3
# 2024-10-31 16:21:03.558 [IPEngine.2] Requesting id: 2
# 2024-10-31 16:21:03.558 [IPEngine.0] Requesting id: 0
# 2024-10-31 16:21:03.560 [IPEngine.2] Shell_addrs: ['tcp://127.0.0.1:35109', 'tcp://127.0.0.1:35551', 'tcp://127.0.0.1:55087']
# 2024-10-31 16:21:03.560 [IPEngine.2] Connecting shell to tcp://127.0.0.1:35109
# 2024-10-31 16:21:03.560 [IPEngine.2] Connecting shell to tcp://127.0.0.1:35551
# 2024-10-31 16:21:03.560 [IPEngine.2] Connecting shell to tcp://127.0.0.1:55087
# 2024-10-31 16:21:03.560 [IPEngine.2] Starting nanny
# 2024-10-31 16:21:03.561 [IPEngine.1] Shell_addrs: ['tcp://127.0.0.1:35109', 'tcp://127.0.0.1:35551', 'tcp://127.0.0.1:40031']
# 2024-10-31 16:21:03.561 [IPEngine.1] Connecting shell to tcp://127.0.0.1:35109
# 2024-10-31 16:21:03.561 [IPEngine.1] Connecting shell to tcp://127.0.0.1:35551
# 2024-10-31 16:21:03.561 [IPEngine.1] Connecting shell to tcp://127.0.0.1:40031
# 2024-10-31 16:21:03.561 [IPEngine.1] Starting nanny
# 2024-10-31 16:21:03.562 [IPEngine.0] Shell_addrs: ['tcp://127.0.0.1:35109', 'tcp://127.0.0.1:35551', 'tcp://127.0.0.1:55087']
# 2024-10-31 16:21:03.562 [IPEngine.0] Connecting shell to tcp://127.0.0.1:35109
# 2024-10-31 16:21:03.562 [IPEngine.0] Connecting shell to tcp://127.0.0.1:35551
# 2024-10-31 16:21:03.562 [IPEngine.0] Connecting shell to tcp://127.0.0.1:55087
# 2024-10-31 16:21:03.562 [IPEngine.0] Starting nanny
# 2024-10-31 16:21:03.562 [IPEngine.3] Shell_addrs: ['tcp://127.0.0.1:35109', 'tcp://127.0.0.1:35551', 'tcp://127.0.0.1:40031']
# 2024-10-31 16:21:03.562 [IPEngine.3] Connecting shell to tcp://127.0.0.1:35109
# 2024-10-31 16:21:03.562 [IPEngine.3] Connecting shell to tcp://127.0.0.1:35551
# 2024-10-31 16:21:03.562 [IPEngine.3] Connecting shell to tcp://127.0.0.1:40031
# 2024-10-31 16:21:03.562 [IPEngine.3] Starting nanny
# 2024-10-31 16:21:03.793 [KernelNanny.1] Starting kernel nanny for engine 1, pid=1447746, nanny pid=1447762
# 2024-10-31 16:21:03.793 [KernelNanny.1] Nanny watching parent pid 1447746.
# 2024-10-31 16:21:03.793 [KernelNanny.0] Starting kernel nanny for engine 0, pid=1447745, nanny pid=1447763
# 2024-10-31 16:21:03.793 [KernelNanny.0] Nanny watching parent pid 1447745.
# 2024-10-31 16:21:03.797 [KernelNanny.2] Starting kernel nanny for engine 2, pid=1447747, nanny pid=1447761
# 2024-10-31 16:21:03.797 [KernelNanny.2] Nanny watching parent pid 1447747.
# 2024-10-31 16:21:03.798 [KernelNanny.3] Starting kernel nanny for engine 3, pid=1447748, nanny pid=1447764
# 2024-10-31 16:21:03.798 [KernelNanny.3] Nanny watching parent pid 1447748.
# 2024-10-31 16:21:03.833 [IPEngine.1] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:03.834 [IPEngine.0] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:03.835 [IPEngine.1] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:03.836 [IPEngine.0] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:03.836 [IPEngine.1] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:03.836 [IPEngine.1] Completed registration with id 1
# 2024-10-31 16:21:03.837 [IPEngine.0] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:03.837 [IPEngine.2] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:03.837 [IPEngine.0] Completed registration with id 0
# 2024-10-31 16:21:03.838 [IPEngine.2] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:03.839 [IPEngine.3] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:03.840 [IPEngine.2] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:03.840 [IPEngine.2] Completed registration with id 2
# 2024-10-31 16:21:03.841 [IPEngine.3] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:03.842 [IPEngine.3] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:03.842 [IPEngine.3] Completed registration with id 3
# 2024-10-31 16:21:08.768 [IPEngine.0] Handling apply_request: 6a176523-0f89635b9aaae2cddaba4a92_1445715_1
# 2024-10-31 16:21:08.768 [IPEngine.2] Handling apply_request: 6a176523-0f89635b9aaae2cddaba4a92_1445715_3
# 2024-10-31 16:21:08.768 [IPEngine.3] Handling apply_request: 6a176523-0f89635b9aaae2cddaba4a92_1445715_4
# 2024-10-31 16:21:08.768 [IPEngine.1] Handling apply_request: 6a176523-0f89635b9aaae2cddaba4a92_1445715_2
#
# engine set stopped 1730406063: {'exit_code': 1, 'pid': 1447740, 'identifier': 'ipengine-1730406062-yqq5-1730406063-1445715'}
# [18.162436537997564, 18.16218676599965, 18.161941098005627, 18.16158084300696]
# Elapsed times: [18.162436537997564, 18.16218676599965, 18.161941098005627, 18.16158084300696] seconds, max runtime=1.82e+01
# Running with 8 processes
# /tmp/ipykernel_1445715/2137199539.py:42: RuntimeWarning: coroutine 'Cluster.stop_cluster' was never awaited
#   cluster.stop_cluster()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /tmp/ipykernel_1445715/2137199539.py:46: RuntimeWarning: coroutine 'Cluster.stop_cluster' was never awaited
#   cluster.stop_cluster()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Starting 8 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
# 100%|██████████| 8/8 [00:05<00:00,  1.45engine/s]
# Stopping controller
# Controller stopped: {'exit_code': 0, 'pid': 1447952, 'identifier': 'ipcontroller-1730406087-j665-1445715'}
# Stopping engine(s): 1730406088
# Output for ipengine-1730406087-j665-1730406088-1445715:
# 2024-10-31 16:21:29.111 [IPEngine.4] Connecting shell to tcp://127.0.0.1:40329
# 2024-10-31 16:21:29.111 [IPEngine.4] Starting nanny
# 2024-10-31 16:21:29.111 [IPEngine.7] Shell_addrs: ['tcp://127.0.0.1:56139', 'tcp://127.0.0.1:35605', 'tcp://127.0.0.1:53825']
# 2024-10-31 16:21:29.111 [IPEngine.7] Connecting shell to tcp://127.0.0.1:56139
# 2024-10-31 16:21:29.112 [IPEngine.7] Connecting shell to tcp://127.0.0.1:35605
# 2024-10-31 16:21:29.112 [IPEngine.7] Connecting shell to tcp://127.0.0.1:53825
# 2024-10-31 16:21:29.112 [IPEngine.7] Starting nanny
# 2024-10-31 16:21:29.112 [IPEngine.1] Shell_addrs: ['tcp://127.0.0.1:56139', 'tcp://127.0.0.1:35605', 'tcp://127.0.0.1:53825']
# 2024-10-31 16:21:29.112 [IPEngine.1] Connecting shell to tcp://127.0.0.1:56139
# 2024-10-31 16:21:29.112 [IPEngine.1] Connecting shell to tcp://127.0.0.1:35605
# 2024-10-31 16:21:29.112 [IPEngine.1] Connecting shell to tcp://127.0.0.1:53825
# 2024-10-31 16:21:29.112 [IPEngine.1] Starting nanny
# 2024-10-31 16:21:29.388 [KernelNanny.6] Starting kernel nanny for engine 6, pid=1447997, nanny pid=1448023
# 2024-10-31 16:21:29.389 [KernelNanny.6] Nanny watching parent pid 1447997.
# 2024-10-31 16:21:29.397 [KernelNanny.3] Starting kernel nanny for engine 3, pid=1447994, nanny pid=1448024
# 2024-10-31 16:21:29.397 [KernelNanny.3] Nanny watching parent pid 1447994.
# 2024-10-31 16:21:29.398 [KernelNanny.5] Starting kernel nanny for engine 5, pid=1447996, nanny pid=1448027
# 2024-10-31 16:21:29.398 [KernelNanny.5] Nanny watching parent pid 1447996.
# 2024-10-31 16:21:29.402 [KernelNanny.7] Starting kernel nanny for engine 7, pid=1447998, nanny pid=1448029
# 2024-10-31 16:21:29.402 [KernelNanny.7] Nanny watching parent pid 1447998.
# 2024-10-31 16:21:29.405 [KernelNanny.4] Starting kernel nanny for engine 4, pid=1447995, nanny pid=1448028
# 2024-10-31 16:21:29.405 [KernelNanny.0] Starting kernel nanny for engine 0, pid=1447991, nanny pid=1448026
# 2024-10-31 16:21:29.405 [KernelNanny.4] Nanny watching parent pid 1447995.
# 2024-10-31 16:21:29.405 [KernelNanny.0] Nanny watching parent pid 1447991.
# 2024-10-31 16:21:29.411 [KernelNanny.1] Starting kernel nanny for engine 1, pid=1447992, nanny pid=1448030
# 2024-10-31 16:21:29.411 [KernelNanny.1] Nanny watching parent pid 1447992.
# 2024-10-31 16:21:29.413 [KernelNanny.2] Starting kernel nanny for engine 2, pid=1447993, nanny pid=1448025
# 2024-10-31 16:21:29.413 [KernelNanny.2] Nanny watching parent pid 1447993.
# 2024-10-31 16:21:29.446 [IPEngine.6] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:29.448 [IPEngine.6] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:29.450 [IPEngine.6] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:29.450 [IPEngine.6] Completed registration with id 6
# 2024-10-31 16:21:29.452 [IPEngine.3] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:29.452 [IPEngine.5] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:29.454 [IPEngine.5] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:29.455 [IPEngine.3] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:29.456 [IPEngine.3] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:29.457 [IPEngine.5] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:29.457 [IPEngine.3] Completed registration with id 3
# 2024-10-31 16:21:29.457 [IPEngine.5] Completed registration with id 5
# 2024-10-31 16:21:29.457 [IPEngine.0] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:29.458 [IPEngine.0] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:29.459 [IPEngine.4] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:29.460 [IPEngine.0] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:29.460 [IPEngine.0] Completed registration with id 0
# 2024-10-31 16:21:29.461 [IPEngine.7] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:29.461 [IPEngine.4] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:29.462 [IPEngine.7] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:29.462 [IPEngine.4] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:29.462 [IPEngine.4] Completed registration with id 4
# 2024-10-31 16:21:29.463 [IPEngine.7] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:29.463 [IPEngine.7] Completed registration with id 7
# 2024-10-31 16:21:29.467 [IPEngine.2] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:29.468 [IPEngine.2] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:29.468 [IPEngine.1] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:29.469 [IPEngine.2] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:29.469 [IPEngine.2] Completed registration with id 2
# 2024-10-31 16:21:29.469 [IPEngine.1] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:29.471 [IPEngine.1] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:29.471 [IPEngine.1] Completed registration with id 1
# 2024-10-31 16:21:34.223 [IPEngine.3] Handling apply_request: 3b6c8ef4-a95f95f62af34bc4f9cd7924_1445715_4
# 2024-10-31 16:21:34.223 [IPEngine.0] Handling apply_request: 3b6c8ef4-a95f95f62af34bc4f9cd7924_1445715_1
# 2024-10-31 16:21:34.223 [IPEngine.1] Handling apply_request: 3b6c8ef4-a95f95f62af34bc4f9cd7924_1445715_2
# 2024-10-31 16:21:34.223 [IPEngine.4] Handling apply_request: 3b6c8ef4-a95f95f62af34bc4f9cd7924_1445715_5
# 2024-10-31 16:21:34.223 [IPEngine.5] Handling apply_request: 3b6c8ef4-a95f95f62af34bc4f9cd7924_1445715_6
# 2024-10-31 16:21:34.223 [IPEngine.7] Handling apply_request: 3b6c8ef4-a95f95f62af34bc4f9cd7924_1445715_8
# 2024-10-31 16:21:34.223 [IPEngine.6] Handling apply_request: 3b6c8ef4-a95f95f62af34bc4f9cd7924_1445715_7
# 2024-10-31 16:21:34.224 [IPEngine.2] Handling apply_request: 3b6c8ef4-a95f95f62af34bc4f9cd7924_1445715_3
#
# engine set stopped 1730406088: {'exit_code': 1, 'pid': 1447986, 'identifier': 'ipengine-1730406087-j665-1730406088-1445715'}
# [17.18519758799812, 17.177563192002708, 17.183756337006344, 17.184789099992486, 17.18213097199623, 17.18448432299192, 17.182081980994553, 17.17947881401051]
# Elapsed times: [17.18519758799812, 17.177563192002708, 17.183756337006344, 17.184789099992486, 17.18213097199623, 17.18448432299192, 17.182081980994553, 17.17947881401051] seconds, max runtime=1.72e+01
# Running with 16 processes
# /tmp/ipykernel_1445715/2137199539.py:42: RuntimeWarning: coroutine 'Cluster.stop_cluster' was never awaited
#   cluster.stop_cluster()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /tmp/ipykernel_1445715/2137199539.py:46: RuntimeWarning: coroutine 'Cluster.stop_cluster' was never awaited
#   cluster.stop_cluster()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Starting 16 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
# 100%|██████████| 16/16 [00:05<00:00,  2.90engine/s]
# Stopping controller
# Controller stopped: {'exit_code': 0, 'pid': 1448263, 'identifier': 'ipcontroller-1730406112-a2pv-1445715'}
# Stopping engine(s): 1730406113
# Output for ipengine-1730406112-a2pv-1730406113-1445715:
#
# 2024-10-31 16:21:54.294 [IPEngine.12] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:54.296 [IPEngine.12] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:54.296 [IPEngine.12] Completed registration with id 12
# 2024-10-31 16:21:54.299 [IPEngine.15] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:54.301 [IPEngine.15] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:54.302 [IPEngine.15] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:54.302 [IPEngine.13] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:54.302 [IPEngine.15] Completed registration with id 15
# 2024-10-31 16:21:54.303 [IPEngine.8] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:54.304 [IPEngine.13] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:54.304 [IPEngine.8] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:54.305 [IPEngine.14] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:54.305 [IPEngine.0] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:54.305 [IPEngine.8] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:54.306 [IPEngine.9] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:54.306 [IPEngine.13] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:54.306 [IPEngine.8] Completed registration with id 8
# 2024-10-31 16:21:54.306 [IPEngine.13] Completed registration with id 13
# 2024-10-31 16:21:54.306 [IPEngine.14] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:54.306 [IPEngine.0] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:54.307 [IPEngine.9] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:54.308 [IPEngine.14] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:54.308 [IPEngine.14] Completed registration with id 14
# 2024-10-31 16:21:54.308 [IPEngine.0] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:54.308 [IPEngine.0] Completed registration with id 0
# 2024-10-31 16:21:54.309 [IPEngine.11] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:54.309 [IPEngine.2] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:54.309 [IPEngine.9] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:54.309 [IPEngine.9] Completed registration with id 9
# 2024-10-31 16:21:54.310 [IPEngine.11] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:54.311 [IPEngine.2] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:54.311 [IPEngine.1] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:54.311 [IPEngine.11] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:54.312 [IPEngine.11] Completed registration with id 11
# 2024-10-31 16:21:54.312 [IPEngine.2] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:54.312 [IPEngine.2] Completed registration with id 2
# 2024-10-31 16:21:54.312 [IPEngine.1] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:54.313 [IPEngine.1] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:54.313 [IPEngine.1] Completed registration with id 1
# 2024-10-31 16:21:54.315 [IPEngine.5] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2024-10-31 16:21:54.316 [IPEngine.5] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-10-31 16:21:54.318 [IPEngine.5] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-10-31 16:21:54.318 [IPEngine.5] Completed registration with id 5
# 2024-10-31 16:21:58.798 [IPEngine.2] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_3
# 2024-10-31 16:21:58.798 [IPEngine.3] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_4
# 2024-10-31 16:21:58.798 [IPEngine.0] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_1
# 2024-10-31 16:21:58.798 [IPEngine.1] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_2
# 2024-10-31 16:21:58.798 [IPEngine.4] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_5
# 2024-10-31 16:21:58.798 [IPEngine.6] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_7
# 2024-10-31 16:21:58.799 [IPEngine.8] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_9
# 2024-10-31 16:21:58.799 [IPEngine.7] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_8
# 2024-10-31 16:21:58.799 [IPEngine.5] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_6
# 2024-10-31 16:21:58.799 [IPEngine.10] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_11
# 2024-10-31 16:21:58.799 [IPEngine.11] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_12
# 2024-10-31 16:21:58.800 [IPEngine.12] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_13
# 2024-10-31 16:21:58.801 [IPEngine.9] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_10
# 2024-10-31 16:21:58.801 [IPEngine.13] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_14
# 2024-10-31 16:21:58.801 [IPEngine.15] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_16
# 2024-10-31 16:21:58.801 [IPEngine.14] Handling apply_request: 697c8180-bcb19d5d7c7be2721271f6ad_1445715_15
#
# engine set stopped 1730406113: {'exit_code': 1, 'pid': 1448297, 'identifier': 'ipengine-1730406112-a2pv-1730406113-1445715'}
# [35.96761748899007, 35.99952382300398, 35.98888891500246, 35.9496553200006, 35.95428408200678, 35.975207769006374, 35.97811898600776, 35.98480235700845, 35.97559547399578, 35.96494358198834, 35.977512511002715, 35.97362947900547, 35.963949331999174, 35.95296722400235, 35.97928069799673, 35.98941497100168]
# Elapsed times: [35.96761748899007, 35.99952382300398, 35.98888891500246, 35.9496553200006, 35.95428408200678, 35.975207769006374, 35.97811898600776, 35.98480235700845, 35.97559547399578, 35.96494358198834, 35.977512511002715, 35.97362947900547, 35.963949331999174, 35.95296722400235, 35.97928069799673, 35.98941497100168] seconds, max runtime=3.60e+01
# /tmp/ipykernel_1445715/2137199539.py:42: RuntimeWarning: coroutine 'Cluster.stop_cluster' was never awaited
#   cluster.stop_cluster()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /tmp/ipykernel_1445715/2137199539.py:46: RuntimeWarning: coroutine 'Cluster.stop_cluster' was never awaited
#   cluster.stop_cluster()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
import matplotlib.pyplot as plt
from festim import __version__


def plot_runtime(
    runtimes_mixed: np.ndarray = None,
    runtimes_change_of_var: np.ndarray = None,
    show_festim_1: bool = True,
    show_ideal: bool = True,
):
    lines = []
    if runtimes_mixed is not None:
        (l_mixed,) = plt.plot(
            num_procs, runtimes_mixed, marker="o", label=f"mixed domain", color="tab:green"
        )
        lines.append(l_mixed)
        if show_ideal:
            n = np.linspace(1, 16, 100)
            (l_ideal,) = plt.plot(
                n, runtimes_mixed[0] * n**-1, linestyle="--", color="tab:grey"
            )
            # lines.append(l_ideal)
    if runtimes_change_of_var is not None:
        (l_change_var,) = plt.plot(
            num_procs,
            runtimes_change_of_var,
            marker="o",
            label="change of variable",
            color="forestgreen",
        )
        lines.append(l_change_var)
        if show_ideal:
            n = np.linspace(1, 16, 100)
            (l_ideal,) = plt.plot(
                n,
                runtimes_change_of_var[0] * n**-1,
                label="ideal",
                linestyle="--",
                color="tab:grey",
            )
            lines.append(l_ideal)

    if show_festim_1:
        # check that runtimes_festim_1.csv exists and plot the results
        try:
            import pandas as pd

            data = pd.read_csv("runtimes_festim_1.csv")
            (l_festim1,) = plt.plot(
                data["num_procs"],
                data["runtimes"],
                marker="o",
                label="FESTIM v1.3.1",
                color="tab:red",
            )
            lines.append(l_festim1)
        except FileNotFoundError:
            print("File runtimes_festim_1.csv not found")

    for line in lines:
        plt.annotate(
            f"{line.get_label()}",
            (num_procs[-1], line.get_ydata()[-1]),
            textcoords="offset points",
            xytext=(5, 0),
            ha="left",
            va="center",
            color=line.get_color(),
        )

    if runtimes_mixed  is not None or runtimes_change_of_var is not None:
        plt.annotate(
            "FESTIM 2",
            (num_procs[2], runtimes_change_of_var[2]),
            textcoords="offset points",
            xytext=(5, 30),
            ha="left",
            va="center",
            color="tab:green",
        )

    # plt.legend()
    plt.xlabel("Number of processes")
    plt.ylabel("Runtime (s)")

    plt.xscale("log")
    plt.yscale("log")

    # xticks only at the powers of 2
    plt.xticks(num_procs, num_procs)

    # remove top and right spines
    plt.gca().spines["top"].set_visible(False)
    plt.gca().spines["right"].set_visible(False)

# show everything
plot_runtime(runtimes_change_of_var=runtimes_change_of_var, runtimes_mixed=runtimes, show_ideal=True)
ylim = plt.gca().get_ylim()
xlim = plt.gca().get_xlim()
plt.show()

# only festim1
plot_runtime()
plt.gca().set_ylim(ylim)
plt.gca().set_xlim(xlim)
plt.show()

# festim1 + change of var
plot_runtime(runtimes_change_of_var=runtimes_change_of_var)
plt.gca().set_ylim(ylim)
plt.gca().set_xlim(xlim)
plt.show()

# festim1 + change of var + mixed
plot_runtime(runtimes_change_of_var=runtimes_change_of_var, runtimes_mixed=runtimes, show_ideal=False)
plt.gca().set_ylim(ylim)
plt.gca().set_xlim(xlim)
plt.show()

# %%
def plot_speedup(
    runtimes_mixed: np.ndarray = None,
    runtimes_change_of_var: np.ndarray = None,
    show_festim_1: bool = True,
    show_ideal: bool = True,
):
    lines = []
    if runtimes_mixed is not None:
        (l_mixed,) = plt.plot(
            num_procs, runtimes_mixed[0] / runtimes_mixed, marker="o", label=f"mixed domain", color="tab:green"
        )
        lines.append(l_mixed)

    if runtimes_change_of_var is not None:
        (l_change_var,) = plt.plot(
            num_procs,
            runtimes_change_of_var[0] / runtimes_change_of_var,
            marker="o",
            label="change of variable",
            color="forestgreen",
        )
        lines.append(l_change_var)

    if show_ideal:
        n = np.linspace(1, 16, 100)
        (l_ideal,) = plt.plot(
            n,
            n,
            label="ideal",
            linestyle="--",
            color="tab:grey",
        )
        lines.append(l_ideal)

    if show_festim_1:
        # check that runtimes_festim_1.csv exists and plot the results
        try:
            import pandas as pd

            data = pd.read_csv("runtimes_festim_1.csv")
            (l_festim1,) = plt.plot(
                data["num_procs"],
                data["runtimes"][0] / data["runtimes"],
                marker="o",
                label="FESTIM v1.3.1",
                color="tab:red",
            )
            lines.append(l_festim1)
        except FileNotFoundError:
            print("File runtimes_festim_1.csv not found")

    for line in lines:
        plt.annotate(
            f"{line.get_label()}",
            (num_procs[-1], line.get_ydata()[-1]),
            textcoords="offset points",
            xytext=(5, 0),
            ha="left",
            va="center",
            color=line.get_color(),
        )

    if runtimes_mixed is not None or runtimes_change_of_var is not None:
        plt.annotate(
            "FESTIM 2",
            (num_procs[2], runtimes[2]/runtimes[0]),
            textcoords="offset points",
            xytext=(5, 60),
            ha="left",
            va="center",
            color="tab:green",
        )

    # move xaxis to y=1
    plt.gca().spines['bottom'].set_position(('data', 1))

    # plt.legend()
    plt.xlabel("Number of processes")
    plt.ylabel("Speedup")

    plt.xscale("log")
    plt.yscale("log")

    # xticks only at the powers of 2
    plt.xticks(num_procs[:-1], num_procs[:-1])

    # remove top and right spines
    plt.gca().spines["top"].set_visible(False)
    plt.gca().spines["right"].set_visible(False)

plot_speedup(runtimes_mixed=runtimes, runtimes_change_of_var=runtimes_change_of_var, show_ideal=True)
